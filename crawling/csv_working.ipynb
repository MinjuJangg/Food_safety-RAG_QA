# %%
import os
import pandas as pd

# %% [markdown]
# # 1
# - 855번부터 수집이 안됨 -> 855번부터 따로 csv 파일 생성

# %%
df = pd.read_csv(r"/home/food/people/minju/crawling/data/result/data_2024_playwright_scraped_11.csv")
df.head()
# Out:
#     국가명        수집일자                                                사이트  \
# 0   캐나다  2020-05-20  https://www.cbc.ca/news/technology/climate-pla...
# 1    미국         NaN  https://www.fsis.usda.gov/news-events/news-pre...
# 2    미국         NaN  https://www.fsis.usda.gov/news-events/news-pre...
# 3  뉴질랜드  2015-04-23  http://www.foodsmart.govt.nz/elibrary/consumer...
# 4    미국  2016-07-06  http://www.usda.gov/wps/portal/usda/usdahome?c...
#
#                                                   제목  \
# 0     [위생용품] 캐나다, COVID-19 팬데믹으로 인해 플라스틱 사용 금지 정책 연기
# 1                         미국 식품안전검사국, 2023년 주요 성과 발표
# 2                     미국 식품안전검사국, 분기별 샘플링 데이터 업데이트 등
# 3  [회수]뉴질랜드 Boundary Road Brewery Ltd, 유리조각 혼입 가능...
# 4                         미국 농무부, 현 정부들어 식품안전 최대로 개선
#
#                                                   내용 정보제공국가      정보구분  \
# 0  COVID-19 팬데믹으로 인해 기후 목표와 플라스틱 사용 규제를 강화하는 캐나다 ...    캐나다  글로벌 동향정보
# 1  미국 식품안전검사국(FSIS)은 식품안전을 통해 공중보건을 보호하고 식품공급망을 강...     미국  글로벌 동향정보
# ...

# %%
df.iloc[855:,].to_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02_02.csv")

# %% [markdown]
# # 2
# - 크롤링 결과 파일 병합

# %%
# 전체 데이터 개수 확인
df = pd.read_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국가명       975 non-null    object
#  1   수집일자      923 non-null    object
#  2   사이트       975 non-null    object
#  3   제목        975 non-null    object
#  4   내용        975 non-null    object
#  5   정보제공국가    975 non-null    object
#  6   정보구분      975 non-null    object
#  7   식품등유형     975 non-null    object
#  8   원인요소      975 non-null    object
#  9   RASFF     975 non-null    bool
#  10  PDF       975 non-null    bool
#  11  REG       975 non-null    bool
#  12  연도        923 non-null    float64
#  13  html      975 non-null    object
#  14  response  975 non-null    int64
# dtypes: bool(3), float64(1), int64(1), object(10)
# memory usage: 94.4+ KB

# %%
df1 = pd.read_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02_result_temp.csv")
df1 = df1.loc[:854,]
df1.tail()
# Out:
#       국가명        수집일자                                                사이트  \
# 850  국제기구  2022-10-19  https://www.fao.org/publications/card/en/c/CC2...
# 851  유럽연합  2016-04-25  http://ec.europa.eu/dgs/health_food-safety/dyn...
# 852    미국  2019-07-13  http://www.journalgazette.net/article/20190712...
# 853   캐나다  2018-06-16  https://www.thestar.com/news/world/2018/06/15/...
# 854    미국  2022-02-16  https://thehill.com/policy/healthcare/594317-t...
#
#                                                     제목  \
# 850   유엔식량농업기구, '세포기반식품의 식품안전측면: 배경문서 3 - 규제 프레임워크' 게재
# 851  EU 집행위 & 보건·환경 리스크 과학위원회(SCHER), 비료성분 '칼슘시안아미드...
# 852  [회수]미국 Ancestral Meats, 제품 수명에 대한 안전성 보장 불가로 염...
# 853                 일본, 미승인 유전자변형 밀 발견으로 캐나다산 밀  수입 중단
# 854  미국 Tyson Foods(사), 켄터키 소재 농장에서 조류인플루엔자 발생...도살...
#
#                                                     내용 정보제공국가      정보구분  \
# 850  유엔식량농업기구(FAO)는 '세포기반식품의 식품안전측면: 배경문서 3 - 규제 프레...   국제기구  글로벌 동향정보
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국가명       963 non-null    object
#  1   수집일자      920 non-null    object
#  2   사이트       963 non-null    object
#  3   제목        963 non-null    object
#  4   내용        963 non-null    object
#  5   정보제공국가    963 non-null    object
#  6   정보구분      963 non-null    object
#  7   식품등유형     963 non-null    object
#  8   원인요소      963 non-null    object
#  9   RASFF     963 non-null    bool
#  10  PDF       963 non-null    bool
#  11  REG       963 non-null    bool
#  12  연도        920 non-null    float64
#  13  html      963 non-null    object
#  14  response  963 non-null    int64
# dtypes: bool(3), float64(1), int64(1), object(10)
# memory usage: 93.2+ KB

# %%
df2 = pd.read_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02_02_result.csv", index_col=0)
df2.head()
# Out:
#              국가명        수집일자  \
# Unnamed: 0
# 855           미국  2016-07-22
# 856           미국  2014-03-18
# 857         유럽연합  2015-01-10
# 858           영국         NaN
# 859           미국  2022-07-14
#
#                                                           사이트  \
# Unnamed: 0
# 855         http://thehill.com/regulation/energy-environme...
# 856         http://sg.news.yahoo.com/wwf-raises-scrutiny-o...
# 857         http://www.efsa.europa.eu/en/efsajournal/pub/3...
# 858         https://uk.news.yahoo.com/no-peanut-found-prod...
# 859         https://www.stltoday.com/news/local/govt-and-p...
#
#                                                            제목  \
# Unnamed: 0
# 855                          미국 환경보호단체, 규제 필요한 유독 화학물질 10종 공개
# 856                   세계자연보호기금, 싱가포르 내 영양각 및 그 제품 거래 실태 조사 제기
# 857         유럽식품안전청, 식품첨가물 Brilliant Black BN (E 151)에 관한 ...
# 858           영국 FGS Ingredients Ltd, 자사 제품에서 땅콩 검출되지 않았다고 밝혀
# ...

# %%
new_df = pd.concat([df1, df2], ignore_index=True)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국가명       975 non-null    object
#  1   수집일자      923 non-null    object
#  2   사이트       975 non-null    object
#  3   제목        975 non-null    object
#  4   내용        975 non-null    object
#  5   정보제공국가    975 non-null    object
#  6   정보구분      975 non-null    object
#  7   식품등유형     975 non-null    object
#  8   원인요소      975 non-null    object
#  9   RASFF     975 non-null    bool
#  10  PDF       975 non-null    bool
#  11  REG       975 non-null    bool
#  12  연도        923 non-null    float64
#  13  html      972 non-null    object
#  14  response  975 non-null    int64
# dtypes: bool(3), float64(1), int64(1), object(10)
# memory usage: 94.4+ KB

# %%
new_df.head()
# Out:
#     국가명        수집일자                                                사이트  \
# 0   캐나다  2016-11-29  http://www.cbc.ca/news/canada/calgary/bovine-t...
# 1    미국         NaN  https://www.cdph.ca.gov/Programs/OPA/Pages/NR2...
# 2    호주  2019-09-16  http://www.agriculture.gov.au/import/industry-...
# 3    미국  2016-10-14  http://www.boston.com/news/food/2016/10/13/she...
# 4  뉴질랜드  2014-09-29  http://www.foodsmart.govt.nz/elibrary/consumer...
#
#                                                   제목  \
# 0                 캐나다, 소 결핵 격리 지역 확대에 살처분 만 여 마리 넘어서
# 1       미국 캘리포니아주 공중보건부, 조류인플루엔자 검출된 원유에 대해 2차 섭취 경고
# 2  호주 농업부, 뉴질랜드산 계육, 계란, 계육제품 및 사료 수입 조건 변경(148-2...
# 3            [회수]미국 매사추세츠주, 노로바이러스 의심 신고사례로 수확 패류 회수
# 4  [회수]뉴질랜드 Progressive Enterprises Ltd, 알레르기 유발물...
#
#                                                   내용 정보제공국가      정보구분  \
# 0  캐나다 연방 당국이 서부 지역에서 발생한 소 결핵으로 살처분 중인 소가 만 여 마리...    캐나다  글로벌 동향정보
# 1  *기수집정보: [회수]미국 Raw Farm, 제품 샘플 중 조류인플루엔자 양성 반응...     미국    위해식품정보
# ...

# %%
new_df.tail()
# Out:
#     국가명        수집일자                                                사이트  \
# 970  미국  2014-08-06  http://wshu.org/post/blumenthal-delauro-call-m...
# 971  호주  2020-08-27  https://www.seymourtelegraph.com.au/rural-news...
# 972  미국         NaN  https://www.newsweek.com/dairy-product-recall-...
# 973  미국  2019-01-09  https://www.fooddive.com/news/residue-of-banne...
# 974  미국         NaN  https://www.mnsenaterepublicans.com/senate-dem...
#
#                                                   제목  \
# 970      미국 의원, FDA에 티스푼 단위로 가당량 표시해 소비자의 이해 높일 것 요구
# 971           호주 빅토리아주 수의국, 케랑 지역의 에뮤 농장에서 조류 독감 발생해
# 972  [회수]미국 Wegmans, 항생제 잔류 여부가 적절히 검사되지 않아 원유 제품 회수
# 973         미국, 캘리포니아주에서 판매된 과채류에서 금지 농약 클로르피리포스 확인돼
# 974      미국 미네소타주 상원 민주당, 곤충 및 세포 배양육 함유 식품 표시 규정 부결
#
#                                                     내용 정보제공국가      정보구분  \
# 970  미국 코네티컷 소속의 리차드 블루멘탈(Richard Blumenthal) 상원과 로...     미국  글로벌 동향정보
# ...

# %%
new_df.to_csv(r"/home/food/people/minju/crawling/data/result/data_2024_playwright_scraped_11.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 new_df.to_csv(r"/home/food/people/minju/crawling/data/result/data_2024_playwright_scraped_11.csv", index=False)
#
# NameError: name 'new_df' is not defined

# %%
df['response'].value_counts()
# Out:
# response
# 200    605
# 403    208
# 401     96
# 404     48
# 999      3
# 101      2
# 410      1
# Name: count, dtype: int64

# %%
# 노가다 개수
print(len(df) - len(df[df['response'] == 200]))
# Out:
# 358

# %% [markdown]
# # 3
# - 노가다

# %%
df = pd.read_csv(r"/home/food/people/minju/crawling/data/result/final.csv")
df1 = pd.read_csv("/home/food/people/minju/crawling/data/result/data_2024_playwright_scraped_11_temp.csv")
df['response'].value_counts()
# Out:
# response
# 200    703
# 401    203
# 404     51
# 999      6
# Name: count, dtype: int64

# %%
df
# Out:
#      Unnamed: 0   국가명        수집일자  \
# 0             0   캐나다  2020-05-20
# 1             1    미국         NaN
# 2             2    미국         NaN
# 3             3  뉴질랜드  2015-04-23
# 4             4    미국  2016-07-06
# ..          ...   ...         ...
# 958         958  유럽연합  2017-10-13
# 959         959  유럽연합  2014-09-13
# 960         960    영국  2016-10-24
# 961         961    미국  2019-04-01
# 962         962    미국  2019-03-15
#
#                                                    사이트  \
# 0    https://www.cbc.ca/news/technology/climate-pla...
# 1    https://www.fsis.usda.gov/news-events/news-pre...
# 2    https://www.fsis.usda.gov/news-events/news-pre...
# 3    http://www.foodsmart.govt.nz/elibrary/consumer...
# 4    http://www.usda.gov/wps/portal/usda/usdahome?c...
# ..                                                 ...
# 958  http://www.europarl.europa.eu/news/en/headline...
# 959  http://www.europarl.europa.eu/news/en/news-roo...
# ...

# %%
df.to_csv("/home/food/people/minju/crawling/data/result/real.csv")

# %%
df['new_html'] = None
df['new_response'] = None

# %%
response_path = "C:/Users/ssl/Desktop/SSL/식품안전/4. 작업 코드/데이터 수집/response/"

# %% [markdown]
# ## response 500 -> 완료

# %%
# response 500: 서버 내부 오류 -> 완료
response_code = 401
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'html'] = 'forbidden' # 일괄 처리
# df.loc[df[df['response']==response_code].index, 'response'] = 999 # 일괄 처리
# Out:
# response code: 401
# idx 1: https://www.fsis.usda.gov/news-events/news-press-releases/fsis-highlights-2023-accomplishments-protecting-public-health-and
# idx 60: https://chemicalwatch.com/74304/belgium-gears-up-for-voluntary-microplastics-ban
# idx 117: https://chemicalwatch.com/84452/washington-expands-scope-of-pfas-food-packaging-alternatives-assessment#overlay-strip
# idx 132: https://chemicalwatch.com/66804/danish-investigation-finds-fluorinated-substances-in-cake-packaging
# idx 145: https://chemicalwatch.com/82386/eu-court-rejects-second-case-against-bpa-svhc-identification#overlay-strip
# idx 249: https://www.fsis.usda.gov/wps/portal/fsis/topics/recalls-and-public-health-alerts/recall-case-archive/archive/2018/recall-057-2018-release
# idx 250: https://www.fsis.usda.gov/wps/portal/fsis/topics/recalls-and-public-health-alerts/recall-case-archive/archive/2018/recall-063-2018-release
# ...

# %%
df['html'][91] = 'wrong url'
# Out:
# /tmp/ipykernel_300162/360864153.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['html'][91] = 'wrong url'
# /tmp/ipykernel_300162/360864153.py:1: SettingWithCopyWarning:
# ...

# %%
df.to_csv(
    '/home/food/people/minju/crawling/data/result/data_2024_playwright_scraped_11.csv',
    index=False,
    encoding='utf-8-sig',
    errors='replace'
)

# %%
df['html'][962] = text.strip()
df['response'][962]= 200
# Out:
# /tmp/ipykernel_300162/4287302380.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['html'][962] = text.strip()
# /tmp/ipykernel_300162/4287302380.py:1: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## response 400 -> 완료

# %%
# response 400: 잘못된 요청 -> 완료
response_code = 999
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'new_html'] = 'page not found' # 일괄 처리
df.loc[df[df['response']==response_code].index, 'new_response'] = 404 # 일괄 처리
# Out:
# response code: 999
# idx 77: - 일시: 2016.9.29
# idx 91: Salmonella in organic soyseed meal
# idx 429: https://www.fsis.usda.gov/wps/portal/fsis/newsroom/news-releases-statements-transcripts/news-release-archives-by-year/archive/2020/pha-01092020-01

# %%
df['html'][429] = '''forbidden'''
# Out:
# /tmp/ipykernel_300162/574558133.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['html'][429] = '''forbidden'''
# /tmp/ipykernel_300162/574558133.py:1: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## response 522 -> 완료

# %%
# response 522: Connection Timed Out -> 완료
response_code = 522
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'new_html'] = 'page not found' # 일괄 처리
df.loc[df[df['response']==response_code].index, 'new_response'] = 404 # 일괄 처리
# Out:
# response code: 522
# idx 150: http://www.unsafefoods.com/2018/01/08/us-restaurants-pull-romaine-amid-e-coli-lettuce-outbreak/

# %% [markdown]
# ## response 503 -> 완료

# %%
# response 503: 서버가 일시적으로 과부하 상태 또는 점검 중 -> 완료
response_code = 503
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'new_html'] = 'page not found' # 일괄 처리
df.loc[df[df['response']==response_code].index, 'new_response'] = 404 # 일괄 처리
# Out:
# response code: 503
# idx 967: http://www.firstcoastnews.com/story/news/local/2014/02/25/legislative-jacksonville-food-truck-proposal/5824895/
# idx 969: http://www.wzzm13.com/story/life/wellness/healthy-you/2015/02/17/food-additives-artificial-flavors/23552255/

# %% [markdown]
# ## response 202 -> 완료

# %%
# response 202: 요청이 수락되었지만, 아직 처리되지 않음 (비동기)
response_code = 202
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/" # reponse code 경로 설정
if not os.path.exists(temp_path): # reponse code 경로가 없으면 생성
    os.makedirs(temp_path)

for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스, 제목, 사이트 주소 출력
    print(f"idx {idx}:")
    print(df.loc[idx, '제목'])
    print(df.loc[idx, '사이트'])
    if not os.path.exists(temp_path+f"{idx}.txt"): # 해당 인덱스에 대한 빈 txt 파일 없으면 생성
        with open(temp_path+f"{idx}.txt", "w") as f:
            pass
# Out:
# response code: 202
# idx 321:
# 미국, 스타벅스 직원이 주문 음식에 부정 행위했다는 소셜 미디어 확산 게시물 거짓으로 드러나
# https://www.seattletimes.com/business/starbucks/a-starbucks-briefly-closes-after-hoax-about-a-barista-defiling-food-goes-viral/
# idx 520:
# [식중독]미국 시애틀, 노로바이러스 식중독 의심으로 이탈리아 식당 폐점
# http://www.seattletimes.com/seattle-news/health/bellevue-maggianos-closed-because-of-suspected-norovirus-outbreak/
# idx 726:
# 중국, 미국 서부해안에서 수확한 패류의 수입금지 해제
# http://seattletimes.com/html/nationworld/2023684283_chinabanxml.html

# %%
# response 202: 요청이 수락되었지만, 아직 처리되지 않음 (비동기)
response_code = 202
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/" # reponse code 경로 설정
if not os.path.exists(temp_path): # reponse code 경로가 없으면 생성
    os.makedirs(temp_path)

files = os.listdir(temp_path) # reponse code 경로에 있는 txt 파일 목록 불러오기
for file in files:
    idx = int(file[:-4]) # 파일 이름에서 인덱스 추출
    with open(temp_path+file, "r") as f: # html 코드가 적힌 txt 파일 열기
        new_html = f.read()

    if new_html.strip() == "": # 빈 파일이면 확인 필요
        print(f"Warning! Check idx {idx}.")
        continue
    df.loc[idx, 'new_html'] = new_html # html 코드를 new_html 컬럼에 입력

    if new_html.strip() == "page not found": # 'page not found'인 경우, response를 404로 입력
        df.loc[idx, 'new_response'] = 404
    elif new_html.strip() == "redirection": # 'redirection'인 경우, response를 999로 입력
        df.loc[idx, 'new_response'] = 999
    elif new_html.strip() == "forbidden":
        df.loc[idx, 'new_response'] = 401 # 'forbidden'인 경우, response를 401로 입력
    else:
        df.loc[idx, 'new_response'] = 200 # 그외, response를 200로 입력
# Out:
# response code: 202

# %% [markdown]
# ## response 101 -> 완료

# %%
# response 101: 클라이언트의 프로토콜 변경 요청을 서버가 수락
response_code = 101
print(f"response code: {response_code}")

# temp_path = response_path + f"response{response_code}/"
# if not os.path.exists(temp_path):
#     os.makedirs(temp_path)

for idx in df[df['response']==response_code].index:
    print(f"idx {idx}:")
    print(df.loc[idx, '제목'])
    print(df.loc[idx, '사이트'])
    # if not os.path.exists(temp_path+f"{idx}.txt"):
    #     with open(temp_path+f"{idx}.txt", "w") as f:
    #         pass
# Out:
# response code: 101

# %%
# response 101: 클라이언트의 프로토콜 변경 요청을 서버가 수락
response_code = 101
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/"
if not os.path.exists(temp_path):
    os.makedirs(temp_path)

files = os.listdir(temp_path)
for file in files:
    idx = int(file[:-4]) # 파일 이름에서 인덱스 추출
    with open(temp_path+file, "r") as f:
        new_html = f.read()

    if new_html.strip() == "":
        print(f"Warning! Check idx {idx}.")
        continue
    df.loc[idx, 'new_html'] = new_html

    if new_html.strip() == "page not found":
        df.loc[idx, 'new_response'] = 404
    elif new_html.strip() == "redirection":
        df.loc[idx, 'new_response'] = 999
    elif new_html.strip() == "forbidden":
        df.loc[idx, 'new_response'] = 401
    else:
        df.loc[idx, 'new_response'] = 200
# Out:
# response code: 101

# %% [markdown]
# ## response 410 -> 완료

# %%
# response 410: 요청한 리소스가 영구적으로 사라짐 -> 완료
response_code = 410
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'new_html'] = 'page not found' # 일괄 처리
df.loc[df[df['response']==response_code].index, 'new_response'] = 404 # 일괄 처리
# Out:
# response code: 410
# idx 212: http://consumerist.com/2014/05/19/rep-slaughter-asks-mcdonalds-to-switch-to-antibiotic-free-beef/
# idx 962: http://www.fox5dc.com/news/181714397-story
# idx 963: https://www.eladelantado.com/us/costco-recall-two-products/
# idx 964: http://www.europarl.europa.eu/news/en/news-room/content/20150413STO41754/html/Five-a-day-how-the-EU-will-help-children-to-learn-about-healthy-eating
# idx 965: http://www.europarl.europa.eu/news/en/news-room/content/20151116STO02882/html/Organic-food-healthier-than-conventional-food
# idx 966: https://www.eladelantado.com/us/costco-recall-two-products/

# %% [markdown]
# ## response 521 -> 완료

# %%
# response 521: 원본 서버가 응답하지 않음 -> 완료
response_code = 521
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'new_html'] = 'page not found' # 일괄 처리
df.loc[df[df['response']==response_code].index, 'new_response'] = 404 # 일괄 처리
# Out:
# response code: 521
# idx 828: http://outbreaknewstoday.com/iceland-reports-norovirus-outbreak-linked-oysters-19022/
# idx 829: http://outbreaknewstoday.com/indiana-first-human-case-h3n2-variant-influenza-reported-since-2013/
# idx 830: http://www.theglobaldispatch.com/russia-rosselkhoznadzor-
# idx 831: http://outbreaknewstoday.com/deli-meat-sold-in-sweden-recalled-due-to-listeria-36588/
# idx 832: http://outbreaknewstoday.com/suspected-aflatoxin-outbreak-reported-in-tanzania-34987/
# idx 833: http://outbreaknewstoday.com/salmonella-in-sweden-outbreak-now-considered-over-47678/

# %% [markdown]
# ## response 999 -> 완료

# %%
# response 999: 디버깅을 위해 임의로 부여한 코드번호(크롤링 중 팝업 제거 실패 등의 이유로 발생한 에러)
response_code = 999
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/"
if not os.path.exists(temp_path):
    os.makedirs(temp_path)

for idx in df[df['response']==response_code].index:
    print(f"idx {idx}:")
    print(df.loc[idx, '제목'])
    print(df.loc[idx, '사이트'])
    if not os.path.exists(temp_path+f"{idx}.txt"):
        with open(temp_path+f"{idx}.txt", "w") as f:
            pass
# Out:
# response code: 999
# idx 4:
# [회수]뉴질랜드 Progressive Enterprises Ltd, 알레르기 유발물질(땅콩) 미표시로 견과류 스프레드 회수
# http://www.foodsmart.govt.nz/elibrary/consumer/woolworths-macro-brazil-almond-cashew-spread.htm#1321
# idx 9:
# 미국 상원, 브라질 소고기 파동 해결될 때까지 브라질산 소고기 수입 중단 촉구
# https://www.heitkamp.senate.gov/public/index.cfm/press-releases?ID=73F24786-0D59-4CA3-B446-617EE9C75B30
# idx 11:
# [회수]미국 Zee Best Foods, Inc., 제품 생산 중 미흡한 온도 관리로 소스 및 즉석섭취식품 회수
# https://datcp.wi.gov/Pages/News_Media/ZeeBestFoodsRecall.aspx
# idx 27:
# 세계보건기구, 알코올로 인한 사망에 대한 공공보건의 성공 및 실패 발표
# http://www.euro.who.int/en/health-topics/disease-prevention/alcohol-use/news/news/2016/09/public-health-successes-and-missed-opportunities-new-report-on-alcohol-attributable-deaths
# idx 29:
# 캐나다 정부, 캐나다산 밀의 콜롬비아 수출 기회 강화
# http://news.gc.ca/web/article-en.do?nid=971009
# idx 31:
# 캐나다 농업농식품부, 채소보존기술 도입 지원
# http://news.gc.ca/web/article-en.do?nid=1006759
# idx 33:
# 네덜란드 보건부, 방역업체 ChickenFriend(사)가 피프로닐 외에 아미트라즈도 사용해
# ...

# %%
# response 999: 디버깅을 위해 임의로 부여한 코드번호(크롤링 중 팝업 제거 실패 등의 이유로 발생한 에러)
response_code = 999
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/"
if not os.path.exists(temp_path):
    os.makedirs(temp_path)

files = os.listdir(temp_path)
for file in files:
    idx = int(file[:-4]) # 파일 이름에서 인덱스 추출
    with open(temp_path+file, "r") as f:
        new_html = f.read()

    if new_html.strip() == "":
        print(f"Warning! Check idx {idx}.")
        continue
    df.loc[idx, 'new_html'] = new_html

    if new_html.strip() == "page not found":
        df.loc[idx, 'new_response'] = 404
    elif new_html.strip() == "redirection":
        df.loc[idx, 'new_response'] = 999
    elif new_html.strip() == "forbidden":
        df.loc[idx, 'new_response'] = 401
    else:
        df.loc[idx, 'new_response'] = 200
# Out:
# response code: 999

# %% [markdown]
# ## response 401 -> 완료

# %%
# response 401: 인증 필요 (로그인 필요)
response_code = 401
print(f"response code: {response_code}")

# temp_path = response_path + f"response{response_code}/"
# if not os.path.exists(temp_path):
#     os.makedirs(temp_path)

for idx in df[df['response']==response_code].index:
    print(f"idx {idx}:")
    # print(df.loc[idx, '제목'])
    # print(df.loc[idx, '사이트'])
    print(df.loc[idx, 'html'])
    # if not os.path.exists(temp_path+f"{idx}.txt"):
    #     with open(temp_path+f"{idx}.txt", "w") as f:
    #         pass
# Out:
# response code: 401
# idx 1:
# forbidden
# idx 60:
# forbidden
# idx 117:
# forbidden
# idx 132:
# forbidden
# idx 145:
# forbidden
# idx 249:
# forbidden
# idx 250:
# forbidden
# idx 255:
# forbidden
# idx 260:
# forbidden
# idx 263:
# forbidden
# idx 264:
# forbidden
# idx 266:
# forbidden
# idx 274:
# forbidden
# idx 279:
# forbidden
# idx 293:
# forbidden
# idx 297:
# forbidden
# idx 302:
# forbidden
# idx 303:
# forbidden
# idx 304:
# forbidden
# idx 309:
# forbidden
# idx 318:
# forbidden
# idx 325:
# forbidden
# idx 326:
# forbidden
# idx 327:
# forbidden
# idx 328:
# forbidden
# idx 330:
# forbidden
# idx 334:
# forbidden
# idx 337:
# forbidden
# idx 338:
# forbidden
# idx 352:
# forbidden
# idx 354:
# forbidden
# idx 355:
# forbidden
# idx 360:
# forbidden
# idx 361:
# forbidden
# idx 368:
# forbidden
# idx 381:
# forbidden
# idx 383:
# forbidden
# idx 391:
# forbidden
# idx 396:
# forbidden
# idx 397:
# forbidden
# idx 400:
# forbidden
# idx 405:
# forbidden
# idx 406:
# ...

# %%
# response 401: 인증 필요 (로그인 필요)
response_code = 401
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/"
if not os.path.exists(temp_path):
    os.makedirs(temp_path)

files = os.listdir(temp_path)
for file in files:
    idx = int(file[:-4]) # 파일 이름에서 인덱스 추출
    with open(temp_path+file, "r") as f:
        new_html = f.read()
    
    if new_html.strip() == "":
        print(f"Warning! Check idx {idx}.")
        continue
    df.loc[idx, 'new_html'] = new_html

    if new_html.strip() == "page not found":
        df.loc[idx, 'new_response'] = 404
    elif new_html.strip() == "redirection":
        df.loc[idx, 'new_response'] = 999
    elif new_html.strip() == "forbidden":
        df.loc[idx, 'new_response'] = 401
    else:
        df.loc[idx, 'new_response'] = 200
# Out:
# response code: 401

# %% [markdown]
# ## response 404 -> 완료

# %%
# response 404: 요청한 리소스를 찾을 수 없음 -> 완료
response_code = 404
print(f"response code: {response_code}")
for idx in df[df['response']==response_code].index: # response code에 해당하는 인덱스 및 사이트 주소 출력
    print(f"idx {idx}: {df.loc[idx, '사이트']}")

df.loc[df[df['response']==response_code].index, 'new_html'] = 'page not found' # 일괄 처리
df.loc[df[df['response']==response_code].index, 'new_response'] = 404 # 일괄 처리
# Out:
# response code: 404
# idx 3: http://www.foodsmart.govt.nz/elibrary/consumer/boundary-road-brand-founders-1981-pale-ale.htm
# idx 4: http://www.usda.gov/wps/portal/usda/usdahome?contentid=2016/07/0158.xml&navid=NEWS_RELEASE&navtype=RT&parentnav=LATEST_RELEASES&edeployment_action=retrievecontent
# idx 5: http://news.gc.ca/web/article-en.do?nid=841969
# idx 9: http://www.usda.gov/wps/portal/usda/usdahome?contentid=2014/05/0103.xml&navid=NEWS_RELEASE&navtype=RT&parentnav=LATEST_RELEASES&edeployment_action=retrievecontent
# idx 10: http://news.gc.ca/web/article-en.do?nid=897719
# idx 15: https://www.foodstandards.gov.au/industry/foodrecalls/recalls/Pages/Oscar-Caramel-Mylk-Chocolate-.aspx
# idx 25: http://news.gc.ca/web/article-en.do?mthd=index&crtr.page=1&nid=820169
# idx 48: https://www.usda.gov/wps/portal/usda/usdahome?contentid=2016/12/0270.xml&navid=NEWS_RELEASE&navtype=RT&parentnav=LATEST_RELEASES&edeployment_action=retrievecontent
# ...

# %% [markdown]
# ## response 403 -> 완료

# %%
# response 403: 서버가 요청을 거부함 (권한 없음)
response_code = 403
print(f"response code: {response_code}")

# temp_path = response_path + f"response{response_code}/"
# if not os.path.exists(temp_path):
#     os.makedirs(temp_path)

for idx in df[df['response']==response_code].index:
    print(f"idx {idx}:")
    print(df.loc[idx, '제목'])
    print(df.loc[idx, '사이트'])
    # if not os.path.exists(temp_path+f"{idx}.txt"):
    #     with open(temp_path+f"{idx}.txt", "w") as f:
    #         pass
# Out:
# response code: 403
# idx 428:
# 미국, '100% 파마산 치즈'의 표시 기만 관련 집단 소송 기각
# https://www.bna.com/kraft-heinz-others-n73014463651/
# idx 430:
# [회수] 미국 Tarantino Wholesale Foods Distributor, 설익음 가능성으로 즉석섭취 닭가슴살 제품 회수
# https://www.fsis.usda.gov/wps/portal/fsis/topics/recalls-and-public-health-alerts/recall-case-archive/archive/2020/recall-027-2020-release
# idx 431:
# 영국 식품기준청, 설문조사 결과 식품안전에 대한 신뢰 높아
# https://www.foodsafetynews.com/2021/04/fsa-survey-finds-high-confidence-in-food-safety/
# idx 432:
# 미국 연방거래위원회, 금연·체중 감량 ·성기능 보조제 표방 구강용해필름에 대한 불법 마케팅 중단 명령 선고
# https://www.ftc.gov/news-events/news/press-releases/2022/03/federal-court-rules-favor-ftc-halting-illegal-tactics-used-promote-smoking-cessation-weight-loss
# idx 434:
# [회수]미국 Bakkavor Foods USA Inc., 살모넬라 및 리스테리아 오염 가능성으로 즉석섭취 식육 및 가금육 제품 회수
# https://www.fsis.usda.gov/wps/portal/fsis/topics/recalls-and-public-health-alerts/recall-case-archive/archive/2018/recall-103-2018-release
# idx 440:
# ...

# %%
df[]

# %%
# response 403: 서버가 요청을 거부함 (권한 없음)
response_code = 403
print(f"response code: {response_code}")

temp_path = response_path + f"response{response_code}/"
if not os.path.exists(temp_path):
    os.makedirs(temp_path)

files = os.listdir(temp_path)
for file in files:
    idx = int(file[:-4]) # 파일 이름에서 인덱스 추출
    with open(temp_path+file, "r") as f:
        new_html = f.read()

    if new_html.strip() == "":
        print(f"Warning! Check idx {idx}.")
        continue
    df.loc[idx, 'new_html'] = new_html

    if new_html.strip() == "page not found":
        df.loc[idx, 'new_response'] = 404
    elif new_html.strip() == "redirection":
        df.loc[idx, 'new_response'] = 999
    elif new_html.strip() == "forbidden":
        df.loc[idx, 'new_response'] = 401
    else:
        df.loc[idx, 'new_response'] = 200
# Out:
# response code: 403

# %% [markdown]
# ## Final

# %%
# df.to_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02_result_after.csv")

# %%
final = pd.read_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02_result_after.csv", index_col=0)
final.head()
# Out:
#     국가명        수집일자                                                사이트  \
# 0   캐나다  2016-11-29  http://www.cbc.ca/news/canada/calgary/bovine-t...
# 1    미국         NaN  https://www.cdph.ca.gov/Programs/OPA/Pages/NR2...
# 2    호주  2019-09-16  http://www.agriculture.gov.au/import/industry-...
# 3    미국  2016-10-14  http://www.boston.com/news/food/2016/10/13/she...
# 4  뉴질랜드  2014-09-29  http://www.foodsmart.govt.nz/elibrary/consumer...
#
#                                                   제목  \
# 0                 캐나다, 소 결핵 격리 지역 확대에 살처분 만 여 마리 넘어서
# 1       미국 캘리포니아주 공중보건부, 조류인플루엔자 검출된 원유에 대해 2차 섭취 경고
# 2  호주 농업부, 뉴질랜드산 계육, 계란, 계육제품 및 사료 수입 조건 변경(148-2...
# 3            [회수]미국 매사추세츠주, 노로바이러스 의심 신고사례로 수확 패류 회수
# 4  [회수]뉴질랜드 Progressive Enterprises Ltd, 알레르기 유발물...
#
#                                                   내용 정보제공국가      정보구분  \
# 0  캐나다 연방 당국이 서부 지역에서 발생한 소 결핵으로 살처분 중인 소가 만 여 마리...    캐나다  글로벌 동향정보
# 1  *기수집정보: [회수]미국 Raw Farm, 제품 샘플 중 조류인플루엔자 양성 반응...     미국    위해식품정보
# ...

# %%
# response 200 아닌 경우, ['html', 'response'] 값을 ['new_html', 'new_response'] 값으로 변경
not_200_indices = final[final['response'] != 200].index # response가 200이 아닌 인덱스 추출
final.loc[not_200_indices, ['html', 'response']] = final.loc[not_200_indices, ['new_html', 'new_response']].values
# Out:
# C:\Users\ssl\AppData\Local\Temp\ipykernel_5988\4125907278.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 999.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 999.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 404.0, 999.0, 401.0, 200.0, 401.0, 200.0, 401.0, 401.0, 401.0, 200.0, 200.0, 200.0, 401.0, 200.0, 401.0, 401.0, 401.0, 200.0, 404.0, 404.0, 200.0, 401.0, 401.0, 404.0, 200.0, 401.0, 401.0, 200.0,
# ...

# %%
# html 코드 앞뒤로 있는 공백 제거
final['html'] = final['html'].str.strip()

# %%
# reponse 자료형 int로 변환
final['response'] = final['response'].astype(int)

# %%
# 확인
final['new_response'].value_counts().sum() # 576
# Out:
# np.int64(576)

# %%
final['response'].value_counts()
# Out:
# response
# 200    651
# 404    169
# 401    139
# 999     16
# Name: count, dtype: int64

# %%
final[final['response'] != 200]['html'].unique()
# Out:
# array(['page not found', 'redirection', 'forbidden'], dtype=object)

# %%
# new_html, new_response 컬럼 삭제
final.drop(columns=['new_html', 'new_response'], inplace=True)

# %%
final.head()
# Out:
#     국가명        수집일자                                                사이트  \
# 0   캐나다  2016-11-29  http://www.cbc.ca/news/canada/calgary/bovine-t...
# 1    미국         NaN  https://www.cdph.ca.gov/Programs/OPA/Pages/NR2...
# 2    호주  2019-09-16  http://www.agriculture.gov.au/import/industry-...
# 3    미국  2016-10-14  http://www.boston.com/news/food/2016/10/13/she...
# 4  뉴질랜드  2014-09-29  http://www.foodsmart.govt.nz/elibrary/consumer...
#
#                                                   제목  \
# 0                 캐나다, 소 결핵 격리 지역 확대에 살처분 만 여 마리 넘어서
# 1       미국 캘리포니아주 공중보건부, 조류인플루엔자 검출된 원유에 대해 2차 섭취 경고
# 2  호주 농업부, 뉴질랜드산 계육, 계란, 계육제품 및 사료 수입 조건 변경(148-2...
# 3            [회수]미국 매사추세츠주, 노로바이러스 의심 신고사례로 수확 패류 회수
# 4  [회수]뉴질랜드 Progressive Enterprises Ltd, 알레르기 유발물...
#
#                                                   내용 정보제공국가      정보구분  \
# 0  캐나다 연방 당국이 서부 지역에서 발생한 소 결핵으로 살처분 중인 소가 만 여 마리...    캐나다  글로벌 동향정보
# 1  *기수집정보: [회수]미국 Raw Farm, 제품 샘플 중 조류인플루엔자 양성 반응...     미국    위해식품정보
# ...

# %%
# final.to_csv(r"C:\Users\ssl\Desktop\SSL\식품안전\4. 작업 코드\데이터 수집\scraped_others_non200_02_final.csv", index=False)
