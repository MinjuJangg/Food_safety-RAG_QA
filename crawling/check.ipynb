# %%
import pandas as pd

# df = pd.read_csv("/home/food/people/minju/crawling/data/result/data_2024_playwright_scraped_11_temp.csv")/
df1 = pd.read_csv("/home/food/people/minju/crawling/data/result/final.csv")
### 77 91주소 없음

# %%
pd.set_option('display.max_rows', None)       # 모든 행 출력
pd.set_option('display.max_columns', None)    # 모든 열 출력
# pd.set_option('display.max_colwidth', None)   # 열 너비 생략 없이 출력

# html과 response만 출력
print(df1[['html', 'response']])
# Out:
#                                                   html  response
# 0    <!DOCTYPE html>\n    <html lang="en">\n       ...       200
# 1                                            forbidden       401
# 2    <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...       200
# 3                                       page not found       404
# 4                                       page not found       404
# 5                                       page not found       404
# 6    <!DOCTYPE html>\n    <html lang="en">\n       ...       200
# 7    <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...       200
# 8    <!DOCTYPE html>\n<html lang="en-US">\n <head>\...       200
# 9                                       page not found       404
# 10                                      page not found       404
# 11   <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...       200
# 12   <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...       200
# ...

# %%
df1['html'][91] = 'wrong url'
# Out:
# /tmp/ipykernel_1174844/1286609548.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1['html'][91] = 'wrong url'
# /tmp/ipykernel_1174844/1286609548.py:1: SettingWithCopyWarning:
# ...

# %%
import pandas as pd

# 공통 인덱스 기준으로 비교 (index가 동일하다고 가정)
condition = (df1['response'] == 200) & (df['response'] != 200)
mismatch_df = df[condition].index.tolist()

# 결과 출력
print(mismatch_df)
# Out:
# [0, 2, 6, 7, 11, 12, 18, 19, 20, 22, 23, 24, 28, 29, 30, 31, 32, 40, 41, 43, 44, 51, 52, 53, 58, 61, 62, 65, 66, 69, 71, 73, 74, 78, 82, 83, 84, 86, 89, 90, 92, 93, 95, 97, 99, 100, 102, 106, 107, 109, 110, 112, 114, 120, 121, 123, 131, 134, 135, 138, 139, 141, 144, 146, 149, 153, 154, 156, 161, 163, 164, 167, 169, 170, 175, 178, 179, 181, 184, 185, 189, 190, 191, 192, 193, 194, 195, 200, 202, 203, 204, 205, 207, 215, 219, 221, 222, 223, 224, 225, 226, 228, 229, 231, 235, 236, 238, 242, 246, 248, 253, 254, 256, 259, 269, 271, 273, 280, 281, 286, 296, 298, 306, 308, 316, 317, 323, 339, 340, 343, 344, 348, 351, 356, 364, 365, 367, 371, 372, 376, 382, 385, 386, 387, 388, 394, 395, 403, 413, 415, 418, 421, 425, 431, 432, 438, 440, 441, 445, 447, 451, 452, 453, 458, 461, 462, 465, 471, 472, 477, 478, 485, 490, 493, 494, 509, 511, 512, 526, 528, 543, 552, 557, 558, 559, 560, 561, 564, 568, 569, 571, 573, 574, 577, 578, 586, 599, 604, 609, 620, 623, 624, 630, 633, 635, 638, 641, 642, 649, 6
# ...

# %%
print(len(mismatch_df))
for i in range(260):
    if mismatch_df[i] == 509:
        print(i)
        break
# Out:
# 252
# 175

# %%
i = 796
df1['사이트'][i]
# Out:
# 'https://www.foodsafetynews.com/2022/07/officials-warn-of-increase-in-e-coli-infections/'

# %%
df1['html'][i] = t.strip()
# df1['response'][i] = 200
# Out:
# /tmp/ipykernel_3199568/7720191.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1['html'][i] = t.strip()
# /tmp/ipykernel_3199568/7720191.py:1: SettingWithCopyWarning:
# ...

# %%
df1[112:113]
# Out:
#      Unnamed: 0 국가명        수집일자  \
# 112         112  미국  2022-03-11
#
#                                                    사이트  \
# 112  https://www.fsis.usda.gov/recalls-alerts/fsis-...
#
#                                                     제목  \
# 112  미국 식품안전검사국, 이물질 오염으로 회수된 드레싱이 포함된 치킨 샐러드 제품에 대...
#
#                                                     내용 정보제공국가    정보구분  \
# 112  - 일자 : 2022.03.10- 지역 : 미국 Arizona, California...     미국  위해식품정보
#
#                         식품등유형               원인요소  RASFF    PDF   REG      연도  \
# 112  가공식품>식육가공품 및 포장육>식육함유가공품  물리적 위해요소>이물질>플라스틱  False  False  True  2022.0
#
#                                                   html  response
# 112  <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...       200

# %%
df1.to_csv(
    '/home/food/people/minju/crawling/data/result/final.csv',
    index=False,
    encoding='utf-8-sig',
    errors='replace'
)
